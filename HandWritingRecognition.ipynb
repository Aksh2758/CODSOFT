# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
import numpy as np

# Define your vocabulary size and maximum sequence length
vocabulary_size = 50  # Example size, update based on your dataset
max_sequence_len = 100  # Example length, update based on your dataset

# Define mappings (example placeholders, use actual mappings from your dataset)
char_to_int = {'a': 1, 'b': 2, 'c': 3}  # Update with actual character-to-int mapping
int_to_char = {1: 'a', 2: 'b', 3: 'c'}  # Update with actual int-to-character mapping

# Sample data (replace with your actual data)
X_train = np.random.randint(0, vocabulary_size, size=(1000, max_sequence_len))
y_train = np.random.randint(0, vocabulary_size, size=(1000, vocabulary_size))

# Model configuration
embedding_dim = 128
lstm_units = 256

model = Sequential([
    Embedding(input_dim=vocabulary_size, output_dim=embedding_dim, input_length=max_sequence_len),
    LSTM(lstm_units, return_sequences=True),
    LSTM(lstm_units),
    Dense(vocabulary_size, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Fit model
model.fit(X_train, y_train, epochs=20, batch_size=64)

# Generate handwritten text
def generate_text(model, start_seed, num_chars):
    for _ in range(num_chars):
        token_list = [char_to_int.get(c, 0) for c in start_seed]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = np.argmax(model.predict(token_list), axis=-1)
        start_seed += int_to_char.get(predicted[0], '')
    return start_seed

generated_text = generate_text(model, "The quick brown fox", 100)
print(generated_text)
# Out:
# C:\Users\aksha\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 21s 695ms/step - accuracy: 0.0212 - loss: 5045.2075
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 670ms/step - accuracy: 0.0185 - loss: 5765.4058
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 649ms/step - accuracy: 0.0146 - loss: 5802.1870
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 652ms/step - accuracy: 0.0197 - loss: 5828.1509
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 644ms/step - accuracy: 0.0180 - loss: 5842.3760
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 648ms/step - accuracy: 0.0215 - loss: 5858.0952
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 649ms/step - accuracy: 0.0230 - loss: 5863.1274
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 646ms/step - accuracy: 0.0236 - loss: 5843.1758
# Epoch 9/20
# ...

# %%
# Import necessary libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding

# %%
# Define vocabulary size and maximum sequence length
vocabulary_size = 50  # Update based on your dataset
max_sequence_len = 100  # Update based on your dataset

# Define character mappings (update based on your dataset)
char_to_int = {'a': 1, 'b': 2, 'c': 3}  # Example mapping
int_to_char = {1: 'a', 2: 'b', 3: 'c'}  # Example mapping

# %%
# Sample data (replace with actual data from IAM dataset)
X_train = np.random.randint(0, vocabulary_size, size=(1000, max_sequence_len))
y_train = np.random.randint(0, vocabulary_size, size=(1000, vocabulary_size))

# %%
# Define the model architecture
embedding_dim = 128
lstm_units = 256

model = Sequential([
    Embedding(input_dim=vocabulary_size, output_dim=embedding_dim, input_length=max_sequence_len),
    LSTM(lstm_units, return_sequences=True),
    LSTM(lstm_units),
    Dense(vocabulary_size, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(X_train, y_train, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 12s 751ms/step - accuracy: 0.0454 - loss: 5520.3940
# Epoch 2/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 19s 658ms/step - accuracy: 0.0442 - loss: 5505.4004
# Epoch 3/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 638ms/step - accuracy: 0.0390 - loss: 5499.8130
# Epoch 4/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 642ms/step - accuracy: 0.0358 - loss: 5515.0840
# Epoch 5/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 641ms/step - accuracy: 0.0462 - loss: 5499.1035

# %%
# Function to generate handwritten-like text
def generate_text(model, start_seed, num_chars):
    for _ in range(num_chars):
        token_list = [char_to_int.get(c, 0) for c in start_seed]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = np.argmax(model.predict(token_list), axis=-1)
        start_seed += int_to_char.get(predicted[0], '')
    return start_seed

# Generate and print the text
generated_text = generate_text(model, "The quick brown fox", 5)
print(generated_text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# The quick brown fox
